# %%
#Importing required libraries
import pandas as pd
df=pd.read_csv('Correlation.csv')

# %%
#Importing required libraries
import seaborn as sns

# %%
df.head()
# Out:
#            id  avgtotalsteps  avgveryactiveminutes  avgfairlyactiveminutes  \
# 0  8378563200    8717.709677             58.677419               10.258065
# 1  5577150313    8304.433333             87.333333               29.833333
# 2  4388161847   10813.935484             23.161290               20.354839
# 3  4702921684    8572.064516              5.129032               26.032258
# 4  8053475328   14763.290323             85.161290                9.580645
#
#    avglightlyactiveminutes  avgsedentaryminutes  avgcalories  \
# 0               156.096774           716.129032  3436.580645
# 1               147.933333           754.433333  3359.633333
# 2               229.354839           836.677419  3093.870968
# 3               237.483871           766.419355  2965.548387
# 4               150.967742          1148.000000  2945.806452
#
#    avgtotalminutesasleep
# 0             445.129032
# 1             432.000000
# 2             400.173913
# 3             417.481481
# 4             297.000000

# %%
#Correlation
df.corr()
# Out:
#                                id  avgtotalsteps  avgveryactiveminutes  \
# id                       1.000000       0.216151              0.450415
# avgtotalsteps            0.216151       1.000000              0.632106
# avgveryactiveminutes     0.450415       0.632106              1.000000
# avgfairlyactiveminutes   0.037041       0.537021              0.307915
# avglightlyactiveminutes -0.090104       0.563201             -0.060766
# avgsedentaryminutes     -0.129759      -0.506390             -0.197912
# avgcalories              0.421941       0.321572              0.623000
# avgtotalminutesasleep   -0.030263      -0.219686             -0.062825
#
#                          avgfairlyactiveminutes  avglightlyactiveminutes  \
# id                                     0.037041                -0.090104
# avgtotalsteps                          0.537021                 0.563201
# avgveryactiveminutes                   0.307915                -0.060766
# avgfairlyactiveminutes                 1.000000                 0.108973
# avglightlyactiveminutes                0.108973                 1.000000
# avgsedentaryminutes                   -0.386517                -0.591466
# avgcalories                            0.119734                -0.063482
# avgtotalminutesasleep                 -0.146594                -0.204385
#
#                          avgsedentaryminutes  avgcalories  \
# id                                 -0.129759     0.421941
# avgtotalsteps                      -0.506390     0.321572
# avgveryactiveminutes               -0.197912     0.623000
# avgfairlyactiveminutes             -0.386517     0.119734
# avglightlyactiveminutes            -0.591466    -0.063482
# avgsedentaryminutes                 1.000000    -0.054484
# avgcalories                        -0.054484     1.000000
# avgtotalminutesasleep              -0.375677    -0.042241
#
#                          avgtotalminutesasleep
# id                                   -0.030263
# avgtotalsteps                        -0.219686
# avgveryactiveminutes                 -0.062825
# avgfairlyactiveminutes               -0.146594
# avglightlyactiveminutes              -0.204385
# avgsedentaryminutes                  -0.375677
# avgcalories                          -0.042241
# avgtotalminutesasleep                 1.000000

# %%
#Plotting correlation matrix
corr = df.corr()
ax = sns.heatmap(corr, vmin=-1, vmax=1, center=0, cmap='seismic', square=True)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right');
